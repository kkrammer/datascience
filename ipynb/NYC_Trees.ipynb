# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
tree_census = pd.read_csv('2015_Street_Tree_Census_-_Tree_Data.csv')

# %%
tree_census
# Out:
#      tree_id  block_id created_at  tree_dbh  stump_diam        curb_loc  \
# 0          3    501451  5/19/2015        24           0          OnCurb
# 1          4    501451  5/19/2015        20           0          OnCurb
# 2          7    501911  5/19/2015         3           0          OnCurb
# 3          8    501911  5/19/2015         3           0          OnCurb
# 4          9    501911  5/19/2015         4           0          OnCurb
# 5         10    501911  5/19/2015         4           0          OnCurb
# 6         11    501911  5/19/2015         4           0          OnCurb
# 7         12    501911  5/19/2015         4           0          OnCurb
# 8         13    501911  5/19/2015         4           0          OnCurb
# 9         14    501911  5/19/2015         3           0          OnCurb
# 10        15    501911  5/19/2015         3           0          OnCurb
# 11        16    501911  5/19/2015         4           0          OnCurb
# ...

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subnet = tree_census[['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin','steward',
       'sidewalk','problems', 'root_stone','root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subnet
# Out:
#      tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 0          3        24           0          OnCurb  Alive   Good
# 1          4        20           0          OnCurb  Alive   Good
# 2          7         3           0          OnCurb  Alive   Poor
# 3          8         3           0          OnCurb  Alive   Poor
# 4          9         4           0          OnCurb  Alive   Poor
# 5         10         4           0          OnCurb  Alive   Good
# 6         11         4           0          OnCurb  Alive   Good
# 7         12         4           0          OnCurb  Alive   Good
# 8         13         4           0          OnCurb  Alive   Good
# 9         14         3           0          OnCurb  Alive   Good
# 10        15         3           0          OnCurb  Alive   Fair
# 11        16         4           0          OnCurb  Alive   Good
# 12        17         2           0          OnCurb   Dead    NaN
# ...

# %%
#Look at numerical values first
#search for null values
tree_census_subnet.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        5
# spc_latin     5
# steward       5
# sidewalk      5
# problems      5
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
tree_census_subnet[tree_census_subnet['health'].isna()]
# Out:
#      tree_id  tree_dbh  stump_diam curb_loc status health spc_latin steward  \
# 12        17         2           0   OnCurb   Dead    NaN       NaN     NaN
# 18        23         0           3   OnCurb  Stump    NaN       NaN     NaN
# 32        39         0          31   OnCurb  Stump    NaN       NaN     NaN
# 87       122         5           0   OnCurb   Dead    NaN       NaN     NaN
# 119      154         0           5   OnCurb  Stump    NaN       NaN     NaN
#
#     sidewalk problems root_stone root_grate root_other trunk_wire trnk_light  \
# 12       NaN      NaN         No         No         No         No         No
# 18       NaN      NaN         No         No         No         No         No
# 32       NaN      NaN         No         No         No         No         No
# 87       NaN      NaN         No         No         No         No         No
# 119      NaN      NaN         No         No         No         No         No
#
# ...

# %%
tree_census_subnet.describe()
# Out:
#           tree_id    tree_dbh  stump_diam
# count  143.000000  143.000000  143.000000
# mean    90.776224    7.146853    0.272727
# std     54.337420    6.024548    2.632895
# min      3.000000    0.000000    0.000000
# 25%     42.500000    4.000000    0.000000
# 50%     85.000000    5.000000    0.000000
# 75%    141.500000    7.000000    0.000000
# max    177.000000   51.000000   31.000000

# %%
tree_census_subnet.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subnet.hist(bins=60,figsize=(20,10))
# Out:
# array([[<AxesSubplot: title={'center': 'tree_id'}>,
#         <AxesSubplot: title={'center': 'tree_dbh'}>],
#        [<AxesSubplot: title={'center': 'stump_diam'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
tree_census_subnet[tree_census_subnet['tree_dbh']>20]
# Out:
#      tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0          3        24           0   OnCurb  Alive   Good
# 34        41        21           0   OnCurb  Alive   Good
# 54        61        51           0   OnCurb  Alive   Good
# 118      153        25           0   OnCurb  Alive   Good
#
#                               spc_latin steward  sidewalk problems root_stone  \
# 0                     Quercus palustris    1or2    Damage     None         No
# 34                Platanus x acerifolia    None    Damage   Stones        Yes
# 54   Gleditsia triacanthos var. inermis    None  NoDamage     None         No
# 118               Platanus x acerifolia    None    Damage     None         No
#
#     root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 0           No         No         No         No         No         No
# 34          No         No         No         No         No         No
# ...

# %%
big_trees = tree_census_subnet[tree_census_subnet['tree_dbh']>20]

# %%
big_trees[['tree_id','stump_diam']].plot(kind='scatter',x='tree_id',y='stump_diam',figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='tree_id', ylabel='stump_diam'>

# %%
pd.DataFrame(tree_census_subnet['spc_latin'].value_counts()).plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
tree_census_subnet['steward'].value_counts()
# Out:
# None    97
# 1or2    31
# 3or4    10
# Name: steward, dtype: int64
